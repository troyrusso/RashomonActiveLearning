# %% [markdown]
# # Packages

# %%
### Packages ###
import sys
sys.path.append('..')
from utils.Auxiliary import AnalyzeResultsFunction

# %% [markdown]
# Neural Network: One hidden later, a RELU activation function, dropout (to prevent overfitting), and softmax output for classification

# %% [markdown]
# # Set up

# %%
# specific_methods options:
# "RF_PL"
# "RF_QBC"
# "GPC_PL"
# "GPC_BALD"
# "BNN_PL"
# "BNN_BALD"
# "UNREAL_LFR"
# "DUREAL_LFR"

# %%
### Inputs ###
DataFileInput = "MONK3"
specific_methods = ["UNREAL_LFR", "DUREAL_LFR", "RF_QBC", "GPC_BALD"]

# Pass the list to the function
AnalysisResultsOutput = AnalyzeResultsFunction(DataType=DataFileInput, methods_to_plot=specific_methods )

# %%
AnalysisResultsOutput["ShapeTable"].T
# Out:
#              0
# RF_PL       50
# RF_QBC      50
# GPC_PL      50
# GPC_BALD    50
# BNN_PL      50
# BNN_BALD    50
# UNREAL_LFR  50
# DUREAL_LFR  50

# %% [markdown]
# # Trace plots

# %%
AnalysisResultsOutput["TimeTable"]
# Out:
#             Mean (minutes)  Max (minutes)
# Method
# RF_PL                 0.17           0.21
# RF_QBC                0.24           0.30
# GPC_PL                0.03           0.04
# GPC_BALD              0.03           0.05
# BNN_PL                1.50           1.90
# BNN_BALD              1.49           2.02
# UNREAL_LFR            0.58           1.06
# DUREAL_LFR            0.54           0.78

# %%
AnalysisResultsOutput["TracePlotMean"]

# %%
AnalysisResultsOutput["TracePlotVariance"]

# %%
# Refit vs. online update count

# %%
AnalysisResultsOutput["RefitFrequencyPlot"]

# %% [markdown]
# # Tree counts

# %%
AnalysisResultsOutput["TreePlot_UNREAL"]

# %%
AnalysisResultsOutput["TreePlot_DUREAL"]

# %%
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 m
#
# NameError: name 'm' is not defined
