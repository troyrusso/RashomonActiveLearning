# %% [markdown]
# # Packages

# %%
### Packages ###
import sys
sys.path.append('..')
from utils.Auxiliary import AnalyzeResultsFunction

# %%
#

# %%
Results = AnalyzeResultsFunction("Bar7", "02")

# %%
print(Results["ShapeTable"])
# Out:
#    PassiveLearningRF  RandomForestResults  DUREAL  UNREAL
# 0                 50                   50      43      41

# %%
print(Results["TimeTable"])
# Out:
#   DUREAL Mean UNREAL Mean DUREAL max UNREAL max
# 0      161.49      173.54     477.32     457.04

# %%
Results["TracePlotMean"]

# %%
Results["TracePlotVariance"]

# %%
Results["TreePlot"]

# %%
Results["WRSTResults_LatexTable"]
# Out:
#                 PassiveLearning RandomForest   UNREAL DUREAL
# PassiveLearning             1.0
# RandomForest                0.0          1.0
# UNREAL                   0.3622        9e-05      1.0
# DUREAL                  0.48288        7e-05  0.35691    1.0
