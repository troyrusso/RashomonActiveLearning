# %% [markdown]
# # Packages

# %%
### Packages ###
import sys
sys.path.append('..')
from utils.Auxiliary import AnalyzeResultsFunction

# %% [markdown]
# Neural Network: One hidden later, a RELU activation function, dropout to prevent overfitting, and softmax output for classification

# %% [markdown]
# HB: 01, 012, 025
#
# IS: 01, 02, 025
#
# M1: 01, 03
#
# M3: 01, 019
#
# B7: 01, 02
#
# BC: 025
#
# CE: 005, 01
#
# CP: No BNN
#
# FI: No TreeFarms

# %%
Results = AnalyzeResultsFunction("Bar7", "01")
print(Results["ShapeTable"])
print(Results["TimeTable"])
# Out:
#    PassiveLearningRF  RandomForestResults  DUREAL  UNREAL  BALD
# 0                 50                   50      50      50    50
#   DUREAL Mean UNREAL Mean DUREAL max UNREAL max BALD Mean
# 0       26.76       25.81      47.45      47.51     54.06

# %%
Results["TracePlotMean"]
